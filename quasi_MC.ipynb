# %%
import numpy as np 
import matplotlib.pyplot as plt 
from scipy.stats import qmc
sob = qmc.Sobol(5, scramble=False)  #vecteur de dimension 5
latin = qmc.LatinHypercube(2)
plt.style.use('ggplot')

# %%
x = sob.random(1024)
x[:10, 0]
# Out:
# array([0.84545898, 0.59545898, 0.09545898, 0.06420898, 0.56420898,
#        0.81420898, 0.31420898, 0.43920898, 0.93920898, 0.68920898])

# %%
x.shape
# Out:
# (1024, 5)

# %%
plt.hist(x)
# Out:
# (array([[103., 102., 103., 102., 102., 103., 102., 102., 103., 102.],
#         [101., 103., 102., 102., 104., 101., 103., 102., 102., 104.],
#         [103., 102., 103., 102., 102., 103., 101., 102., 103., 103.],
#         [101., 104., 103., 101., 103., 102., 104., 102., 102., 102.],
#         [101., 103., 102., 102., 103., 101., 102., 103., 102., 105.]]),
#  array([2.44140625e-04, 1.00195312e-01, 2.00146484e-01, 3.00097656e-01,
#         4.00048828e-01, 5.00000000e-01, 5.99951172e-01, 6.99902344e-01,
#         7.99853516e-01, 8.99804687e-01, 9.99755859e-01]),
#  <a list of 5 BarContainer objects>)

# %%
x = latin.random(5)
plt.scatter(x[:,0], x[:,1])
